# %%
import os
import pandas as pd

# %%
data = []
for path in os.listdir('data'):
    #I downloaded all the data into files with filename length 12. This'll filter out the other stuff.
    if len(path) != 12:
        continue

    df = pd.read_excel('data/' + path)
    data.append(df)

# %%
predictor = pd.concat(data)
# Out:
# C:\Users\pengj\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
predictor.columns = [str.lower(col) for col in predictor.columns]
predictor['address'] = predictor[['street_number', 'avs_street_name', 'avs_street_sfx']].apply(lambda x: ' '.join(x.astype(str)),axis = 1)

# %%
predictor.to_csv('data/full_predictors.csv')

# %%
predictor = pd.read_csv('data/predictor.csv', engine = 'python')
target = pd.read_csv('data/target.csv')

# %%
target = target.dropna()
target.to_csv('data/target.csv')

# %%
predictor.columns;

# %%
#only issued applications matter
predictor = predictor[predictor['status'] == 'ISSUED'].drop('status', axis = 1)
# Out:
#   File "<ipython-input-94-3e9599a24fc8>", line 2
#     predictor = predictor[predictor['status'] == 'ISSUED'].drop('status', axis = 1):
#                                                                                    ^
# SyntaxError: invalid syntax

# %%
predictor['addr2'] = predictor['address'].apply(lambda x: x.split()).apply(lambda x: ' '.join(x[:-1]))

# %% [markdown]
# <b><big>START HERE</big></b>

# %%
tdates;

# %%
start = pd.to_datetime(predictor['expiration_date'][5])
tdates
target[tdates - start > pd.Timedelta('0 days')]
# Out:
#              date                         Address
# 0      2019-03-16                156 GEARY STREET
# 1      2019-03-15            5343 DIAMOND HEIGHTS
# 2      2019-03-15             2190 LOMBARD STREET
# 3      2019-03-15             505 OFARRELL ST 211
# 4      2019-03-15               335 POWELL STREET
# 5      2019-03-15              2301 MARKET STREET
# 6      2019-03-15                   BRYANT STREET
# 7      2019-03-15                   99 YACHT ROAD
# 8      2019-03-15        3555 CESAR CHAVEZ STREET
# 9      2019-03-15                3533 21ST STREET
# 10     2019-03-15                  130 SOUTH PARK
# 11     2019-03-15        3555 CESAR CHAVEZ STREET
# 12     2019-03-15                    345 ARGUELLO
# 13     2019-03-15             1390 MISSION STREET
# 14     2019-03-15      1500 SOUTH VAN NESS AVENUE
# 15     2019-03-15                 421 TURK STREET
# 16     2019-03-15            1495 VALENCIA STREET
# 17     2019-03-15             390 MISSOURI STREET
# 18     2019-03-15              1272 MARKET STREET
# 19     2019-03-15           400 CLEMENTINA STREET
# 20     2019-03-15              2131 FOLSOM STREET
# 21     2019-03-15                 JOHN MUIR DRIVE
# 22     2019-03-15             1801 VICENTE STREET
# 23     2019-03-15             1449 POTRERO AVENUE
# 24     2019-03-15          3610 WASHINGTON STREET
# 25     2019-03-15                    565 ARGUELLO
# 26     2019-03-15                2010 45TH AVENUE
# 27     2019-03-15              310 ARBALLO DR 12C
# 28     2019-03-14                  MISSION STREET
# 29     2019-03-14                 260 KING ST 781
# ...           ...                             ...
# 94072  2016-03-27             2732 VALLEJO STREET
# 94073  2016-03-27                1686 17TH AVENUE
# 94074  2016-03-27                2782 39TH AVENUE
# 94075  2016-03-27               213 CHURCH STREET
# 94076  2016-03-27  FRANCISCO ST/RICHARDSON AVENUE
# 94077  2016-03-27           GOUGH ST/GREEN STREET
# 94078  2016-03-27               GOUGH ST/BROADWAY
# 94079  2016-03-27        MARKET ST/STEUART STREET
# 94080  2016-03-27         SILVER AV/NAPLES STREET
# 94081  2016-03-27             345 ARGUELLO BL 310
# 94082  2016-03-27             HYDE ST/PINE STREET
# 94083  2016-03-27               462 DUBOCE AVENUE
# 94084  2016-03-27          17TH ST/SANCHEZ STREET
# 94085  2016-03-27      FREMONT ST/HARRISON STREET
# 94086  2016-03-27           2ND ST/BRANNAN STREET
# 94087  2016-03-27              KING ST/3RD STREET
# 94088  2016-03-27           646 WASHINGTON STREET
# 94089  2016-03-27        ALEMANY BL/OTTAWA AVENUE
# 94090  2016-03-27          MISSION ST/29TH STREET
# 94091  2016-03-27                1880 PINE STREET
# 94092  2016-03-27             HYDE ST/PINE STREET
# 94093  2016-03-27               1405 GOUGH STREET
# 94094  2016-03-27              1000 SUTTER STREET
# 94095  2016-03-27                255 BERRY STREET
# 94096  2016-03-27        VAN NESS AV/GREEN STREET
# 94097  2016-03-27              1633 MARKET STREET
# 94098  2016-03-27          OCTAVIA ST/FELL STREET
# 94099  2016-03-27                  900 HYDE ST ER
# 94100  2016-03-27        LAGUNA ST/LOMBARD STREET
# 94101  2016-03-27            1275 COLUMBUS AVENUE
#
# [94093 rows x 2 columns]

# %%
365*5
# Out:
# 1825

# %%
mask1 = (pd.Timedelta('1825 days') > (tdates - start) )
mask2 = (tdates - start) > pd.Timedelta('0 days')

# %%
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#           ...
# 490570    True
# 490571    True
# 490572    True
# 490573    True
# 490574    True
# 490575    True
# 490576    True
# 490577    True
# 490578    True
# 490579    True
# 490580    True
# 490581    True
# 490582    True
# 490583    True
# 490584    True
# 490585    True
# 490586    True
# 490587    True
# 490588    True
# 490589    True
# 490590    True
# 490591    True
# 490592    True
# 490593    True
# 490594    True
# 490595    True
# 490596    True
# 490597    True
# 490598    True
# 490599    True
# Name: date, Length: 490591, dtype: bool

# %%
for i, row in predictor.iterrows():
    date = pd.to_datetime(row['expiration_date'])
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# ...
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda2\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1860         try:
# -> 1861             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1862             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-ac9a648cc4cd> in <module>
#       1 for i, row in predictor.iterrows():
# ----> 2     date = pd.to_datetime(row['expiration_date'])
#       3     print(type(date))
#
# ~\Anaconda2\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     609             result = convert_listlike(arg, box, format)
#     610     else:
# --> 611         result = convert_listlike(np.array([arg]), box, format)[0]
#     612
#     613     return result
#
# ~\Anaconda2\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     300             arg, dayfirst=dayfirst, yearfirst=yearfirst,
#     301             utc=utc, errors=errors, require_iso8601=require_iso8601,
# --> 302             allow_object=True)
#     303
#     304     if tz_parsed is not None:
#
# ~\Anaconda2\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1864             return values.view('i8'), tz_parsed
#    1865         except (ValueError, TypeError):
# -> 1866             raise e
#    1867
#    1868     if tz_parsed is not None:
#
# ~\Anaconda2\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1855             dayfirst=dayfirst,
#    1856             yearfirst=yearfirst,
# -> 1857             require_iso8601=require_iso8601
#    1858         )
#    1859     except ValueError as e:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~\Anaconda2\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1356         return parser(parserinfo).parse(timestr, **kwargs)
#    1357     else:
# -> 1358         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1359
#    1360
#
# ~\Anaconda2\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     652             raise ValueError("String does not contain a date:", timestr)
#     653
# --> 654         ret = self._build_naive(res, default)
#     655
#     656         if not ignoretz:
#
# ~\Anaconda2\lib\site-packages\dateutil\parser\_parser.py in _build_naive(self, res, default)
#    1224             cday = default.day if res.day is None else res.day
#    1225
# -> 1226             if cday > monthrange(cyear, cmonth)[1]:
#    1227                 repl['day'] = monthrange(cyear, cmonth)[1]
#    1228
#
# ~\Anaconda2\lib\calendar.py in monthrange(year, month)
#     122     if not 1 <= month <= 12:
#     123         raise IllegalMonthError(month)
# --> 124     day1 = weekday(year, month, 1)
#     125     ndays = mdays[month] + (month == February and isleap(year))
#     126     return day1, ndays
#
# ~\Anaconda2\lib\calendar.py in weekday(year, month, day)
#     114     """Return weekday (0-6 ~ Mon-Sun) for year (1970-...), month (1-12),
#     115        day (1-31)."""
# --> 116     return datetime.date(year, month, day).weekday()
#     117
#     118
#
# ValueError: year 42726 is out of range

# %%
x = 0
fires_within_5
for row in predictor.iterrows():

# %%
def int_able(string):
    try:
        x = int(string)
    except:
        return False
    return True

# %%
predictor[predictor['address'].apply(lambda x: test in x)]
# Out:
# Empty DataFrame
# Columns: [file_date, estimated cost, proposed use, proposed units, proposed stories, address, list]
# Index: []

# %%
#get the rows there the first word of the address is a number
#in other words, make sure there an address number.
predictor['address'][predictor['address'].apply(lambda x: x.split()[0]).apply(intable)];

# %% [markdown]
# Confirmed: Every single row in this data has an address number that's the first word in the address

# %%
#let's get that list out
predictor['list'] = predictor['address'].apply(lambda x: x.split())

# %%
predictor['address'].apply(lambda x: x.split()[-1]).unique();

# %%
street_names = predictor['address'].apply(lambda x: x.split()[-2]).unique()

# %%
test = '156 GEARY'
target[target['Address'].apply(lambda x: test in x)];

# %%
#let's find stuff with the same second word but different suffix. see if that's a thing?
for name in street_names:
    predictor['address'].apply()

# %%
target;

# %%
predictor['street name'] = predictor['list'].apply(lambda x: x[1])

# %%
predictor['addr2'] = predictor['list'].apply(lambda x: ' '.join(x[:-1]))

# %%
predictor
# Out:
#                   file_date  estimated cost          proposed use  \
# 0       2013-12-23 00:00:00      55000000.0            APARTMENTS
# 1       2014-03-07 00:00:00        285000.0     1 FAMILY DWELLING
# 2       2014-04-04 00:00:00             1.0                   NaN
# 3       2014-04-04 00:00:00             1.0                   NaN
# 4       2014-04-04 00:00:00             1.0                   NaN
# 5       2014-04-04 00:00:00             1.0                   NaN
# 6       2014-04-04 00:00:00             1.0                   NaN
# 7       2014-04-04 00:00:00             1.0                   NaN
# 8       2014-04-29 00:00:00          6000.0     1 FAMILY DWELLING
# 9       2014-05-22 00:00:00         20000.0               ANTENNA
# 10      2014-06-11 00:00:00         20000.0                OFFICE
# 11      2014-06-11 00:00:00         20000.0                OFFICE
# 12      2014-07-10 00:00:00        130000.0     1 FAMILY DWELLING
# 13      2014-07-24 00:00:00       3000000.0          RETAIL SALES
# 14      2014-07-30 00:00:00          8000.0     2 FAMILY DWELLING
# 15      2014-09-26 00:00:00         20000.0   PRKNG GARAGE/PUBLIC
# 16      2014-10-01 00:00:00          2250.0                   NaN
# 17      2014-11-04 00:00:00          1000.0            APARTMENTS
# 18      2014-12-04 00:00:00          1000.0                OFFICE
# 19      2014-12-16 00:00:00        334022.0   TOURIST HOTEL/MOTEL
# 20      2014-12-17 00:00:00          5000.0                   NaN
# 21      2014-12-18 00:00:00        495000.0            APARTMENTS
# 22      2014-12-18 00:00:00        495000.0            APARTMENTS
# 23      2014-12-29 00:00:00        100000.0  PUBLIC ASSMBLY OTHER
# 24      2015-01-23 00:00:00         40000.0            APARTMENTS
# 25      2015-01-23 00:00:00         40000.0            APARTMENTS
# 26      2015-01-26 00:00:00         45000.0            APARTMENTS
# 27      2015-01-29 00:00:00         44000.0     1 FAMILY DWELLING
# 28      2015-02-19 00:00:00         22000.0                SCHOOL
# 29      2015-02-19 00:00:00         50000.0  FOOD/BEVERAGE HNDLNG
# ...                     ...             ...                   ...
# 519452  2019-01-31 00:00:00          6000.0                OFFICE
# 519453  2019-01-31 00:00:00          6000.0                OFFICE
# 519454  2019-01-31 00:00:00        100000.0            APARTMENTS
# 519455  2019-01-31 00:00:00         19650.0            APARTMENTS
# 519456  2019-01-31 00:00:00         19650.0            APARTMENTS
# 519457  2019-01-31 00:00:00         25000.0     2 FAMILY DWELLING
# 519458  2019-01-31 00:00:00         25000.0     2 FAMILY DWELLING
# 519459  2019-01-31 00:00:00         30000.0            APARTMENTS
# 519460  2019-01-31 00:00:00         30000.0            APARTMENTS
# 519461  2019-01-31 00:00:00         50000.0     2 FAMILY DWELLING
# 519462  2019-01-31 00:00:00         20000.0          RETAIL SALES
# 519463  2019-01-31 00:00:00         20000.0            APARTMENTS
# 519464  2019-01-31 00:00:00         45000.0     1 FAMILY DWELLING
# 519465  2019-01-31 00:00:00         20000.0     2 FAMILY DWELLING
# 519466  2019-01-31 00:00:00         20000.0     2 FAMILY DWELLING
# 519467  2019-01-31 00:00:00             1.0     1 FAMILY DWELLING
# 519468  2019-01-31 00:00:00             1.0     1 FAMILY DWELLING
# 519469  2019-01-31 00:00:00          6000.0     1 FAMILY DWELLING
# 519470  2019-01-31 00:00:00         11800.0     1 FAMILY DWELLING
# 519471  2019-01-31 00:00:00         11800.0     1 FAMILY DWELLING
# 519472  2019-01-31 00:00:00         10000.0     1 FAMILY DWELLING
# 519473  2019-01-31 00:00:00             1.0         MANUFACTURING
# 519474  2019-01-31 00:00:00          1000.0                OFFICE
# 519475  2019-01-31 00:00:00             1.0     1 FAMILY DWELLING
# 519476  2019-01-31 00:00:00             1.0     2 FAMILY DWELLING
# 519477  2019-01-31 00:00:00             1.0     2 FAMILY DWELLING
# 519478  2019-01-31 00:00:00             1.0     2 FAMILY DWELLING
# 519479  2019-01-31 00:00:00             1.0     2 FAMILY DWELLING
# 519480  2019-01-31 00:00:00          3500.0     1 FAMILY DWELLING
# 519481  2019-01-31 00:00:00          3500.0     1 FAMILY DWELLING
#
#         proposed units  proposed stories             address  \
# 0                259.0               6.0   1201 TENNESSEE ST
# 1                  1.0               3.0         435 10TH AV
# 2                  NaN               NaN      1127 MARKET ST
# 3                  NaN               NaN      1127 MARKET ST
# 4                  NaN               NaN      1127 MARKET ST
# 5                  NaN               NaN      1127 MARKET ST
# 6                  NaN               NaN      1127 MARKET ST
# 7                  NaN               NaN      1127 MARKET ST
# 8                  1.0               3.0  3935 WASHINGTON ST
# 9                  0.0               2.0        455 IRWIN ST
# 10                 0.0              12.0         201 POST ST
# 11                 0.0              12.0         209 POST ST
# 12                 1.0               2.0        2371 17TH AV
# 13                 0.0              23.0      1455 MARKET ST
# 14                 2.0               2.0    322 LEXINGTON ST
# 15                 NaN               7.0    2130 OFARRELL ST
# 16                 NaN               NaN       1 HALLIDIE PZ
# 17                26.0               8.0        1299 BUSH ST
# 18                 NaN              26.0         222 02ND ST
# 19                 NaN               6.0  28 CYRIL MAGNIN ST
# 20                 NaN               NaN       2675 GEARY BL
# 21                 3.0               3.0        3507 23RD ST
# 22                 3.0               3.0        3509 23RD ST
# 23                 0.0               1.0         333 POST ST
# 24                 5.0               3.0        1417 05TH AV
# 25                 5.0               3.0        1419 05TH AV
# 26                12.0               3.0      40 BUCHANAN ST
# 27                 1.0               2.0      1627 RIVERA ST
# 28                 0.0               2.0        1111 08TH ST
# 29                 0.0               2.0       744 IRVING ST
# ...                ...               ...                 ...
# 519452             NaN              11.0       500 HOWARD ST
# 519453             NaN              11.0       500 HOWARD ST
# 519454             3.0               3.0    2834 SAN JOSE AV
# 519455             3.0               4.0  4440 CALIFORNIA ST
# 519456             3.0               4.0  4440 CALIFORNIA ST
# 519457             2.0               3.0        4470 24TH ST
# 519458             2.0               3.0        4472 24TH ST
# 519459           449.0              13.0     601 VAN NESS AV
# 519460           449.0              13.0     601 VAN NESS AV
# 519461             2.0               4.0       7039 GEARY BL
# 519462            10.0               3.0      1795 HAIGHT ST
# 519463             5.0               3.0      785 CORBETT AV
# 519464             1.0               3.0  839 NORTH POINT ST
# 519465             2.0               3.0       3440 SCOTT ST
# 519466             2.0               3.0       3442 SCOTT ST
# 519467             1.0               3.0         513 08TH AV
# 519468             1.0               3.0         513 08TH AV
# 519469             1.0               2.0       766 VIENNA ST
# 519470             1.0               2.0       679 VIENNA ST
# 519471             1.0               2.0       679 VIENNA ST
# 519472             1.0               2.0       766 VIENNA ST
# 519473             NaN               3.0      1155 BRYANT ST
# 519474             NaN               2.0       432 BRYANT ST
# 519475             1.0               2.0         647 28TH AV
# 519476             2.0               3.0        2908 BUSH ST
# 519477             2.0               3.0        2910 BUSH ST
# 519478             2.0               3.0        2908 BUSH ST
# 519479             2.0               3.0        2910 BUSH ST
# 519480             1.0               2.0       274 TOPEKA AV
# 519481             1.0               2.0       274 TOPEKA AV
#
#                            list street name            addr2
# 0         [1201, TENNESSEE, ST]   TENNESSEE   1201 TENNESSEE
# 1               [435, 10TH, AV]        10TH         435 10TH
# 2            [1127, MARKET, ST]      MARKET      1127 MARKET
# 3            [1127, MARKET, ST]      MARKET      1127 MARKET
# 4            [1127, MARKET, ST]      MARKET      1127 MARKET
# 5            [1127, MARKET, ST]      MARKET      1127 MARKET
# 6            [1127, MARKET, ST]      MARKET      1127 MARKET
# 7            [1127, MARKET, ST]      MARKET      1127 MARKET
# 8        [3935, WASHINGTON, ST]  WASHINGTON  3935 WASHINGTON
# 9              [455, IRWIN, ST]       IRWIN        455 IRWIN
# 10              [201, POST, ST]        POST         201 POST
# 11              [209, POST, ST]        POST         209 POST
# 12             [2371, 17TH, AV]        17TH        2371 17TH
# 13           [1455, MARKET, ST]      MARKET      1455 MARKET
# 14         [322, LEXINGTON, ST]   LEXINGTON    322 LEXINGTON
# 15         [2130, OFARRELL, ST]    OFARRELL    2130 OFARRELL
# 16            [1, HALLIDIE, PZ]    HALLIDIE       1 HALLIDIE
# 17             [1299, BUSH, ST]        BUSH        1299 BUSH
# 18              [222, 02ND, ST]        02ND         222 02ND
# 19      [28, CYRIL, MAGNIN, ST]       CYRIL  28 CYRIL MAGNIN
# 20            [2675, GEARY, BL]       GEARY       2675 GEARY
# 21             [3507, 23RD, ST]        23RD        3507 23RD
# 22             [3509, 23RD, ST]        23RD        3509 23RD
# 23              [333, POST, ST]        POST         333 POST
# 24             [1417, 05TH, AV]        05TH        1417 05TH
# 25             [1419, 05TH, AV]        05TH        1419 05TH
# 26           [40, BUCHANAN, ST]    BUCHANAN      40 BUCHANAN
# 27           [1627, RIVERA, ST]      RIVERA      1627 RIVERA
# 28             [1111, 08TH, ST]        08TH        1111 08TH
# 29            [744, IRVING, ST]      IRVING       744 IRVING
# ...                         ...         ...              ...
# 519452        [500, HOWARD, ST]      HOWARD       500 HOWARD
# 519453        [500, HOWARD, ST]      HOWARD       500 HOWARD
# 519454    [2834, SAN, JOSE, AV]         SAN    2834 SAN JOSE
# 519455   [4440, CALIFORNIA, ST]  CALIFORNIA  4440 CALIFORNIA
# 519456   [4440, CALIFORNIA, ST]  CALIFORNIA  4440 CALIFORNIA
# 519457         [4470, 24TH, ST]        24TH        4470 24TH
# 519458         [4472, 24TH, ST]        24TH        4472 24TH
# 519459     [601, VAN, NESS, AV]         VAN     601 VAN NESS
# 519460     [601, VAN, NESS, AV]         VAN     601 VAN NESS
# 519461        [7039, GEARY, BL]       GEARY       7039 GEARY
# 519462       [1795, HAIGHT, ST]      HAIGHT      1795 HAIGHT
# 519463       [785, CORBETT, AV]     CORBETT      785 CORBETT
# 519464  [839, NORTH, POINT, ST]       NORTH  839 NORTH POINT
# 519465        [3440, SCOTT, ST]       SCOTT       3440 SCOTT
# 519466        [3442, SCOTT, ST]       SCOTT       3442 SCOTT
# 519467          [513, 08TH, AV]        08TH         513 08TH
# 519468          [513, 08TH, AV]        08TH         513 08TH
# 519469        [766, VIENNA, ST]      VIENNA       766 VIENNA
# 519470        [679, VIENNA, ST]      VIENNA       679 VIENNA
# 519471        [679, VIENNA, ST]      VIENNA       679 VIENNA
# 519472        [766, VIENNA, ST]      VIENNA       766 VIENNA
# 519473       [1155, BRYANT, ST]      BRYANT      1155 BRYANT
# 519474        [432, BRYANT, ST]      BRYANT       432 BRYANT
# 519475          [647, 28TH, AV]        28TH         647 28TH
# 519476         [2908, BUSH, ST]        BUSH        2908 BUSH
# 519477         [2910, BUSH, ST]        BUSH        2910 BUSH
# 519478         [2908, BUSH, ST]        BUSH        2908 BUSH
# 519479         [2910, BUSH, ST]        BUSH        2910 BUSH
# 519480        [274, TOPEKA, AV]      TOPEKA       274 TOPEKA
# 519481        [274, TOPEKA, AV]      TOPEKA       274 TOPEKA
#
# [519482 rows x 9 columns]

# %%
for i, addr in enumerate(predictor['addr2'].unique()):
    t = target[target['Address'].apply(lambda x: addr in x)].count()
    print(addr, ': ', t['Address'])
    if i > 100: 
        break
# Out:
# 1201 TENNESSEE :  11
# 435 10TH :  1
# 1127 MARKET :  4
# 3935 WASHINGTON :  1
# 455 IRWIN :  3
# 201 POST :  33
# 209 POST :  1
# 2371 17TH :  2
# 1455 MARKET :  68
# 322 LEXINGTON :  0
# 2130 OFARRELL :  21
# 1 HALLIDIE :  0
# 1299 BUSH :  9
# 222 02ND :  1
# 28 CYRIL MAGNIN :  9
# 2675 GEARY :  111
# 3507 23RD :  1
# 3509 23RD :  1
# 333 POST :  136
# 1417 05TH :  0
# 1419 05TH :  0
# 40 BUCHANAN :  9
# 1627 RIVERA :  0
# 1111 08TH :  0
# 744 IRVING :  6
# 130 SAN BUENAVENTURA :  0
# 747 HOWARD :  190
# 1225 HYDE :  2
# 1649 POLK :  1
# 634 MISSOURI :  1
# 650 CALIFORNIA :  72
# 549 FLOOD :  0
# 350 MISSION :  54
# 301 HOWARD :  80
# 1939 MARKET :  3
# 112 07TH :  0
# 212 CALIFORNIA :  7
# 165 LOWER :  0
# 167 LOWER :  0
# 806 35TH :  0
# 536 MISSION :  33
# 195 EUREKA :  1
# 444 DE HARO :  25
# 2526 FRANCISCO :  1
# 1770 35TH :  1
# 312 TEXAS :  1
# 16 25TH NORTH :  0
# 5 EMBARCADERO CENTER :  0
# 1263 MISSION :  1
# 727 CHENERY :  0
# 733 CHENERY :  0
# 703 MARKET :  14
# 975 CLAYTON :  0
# 2849 BALBOA :  0
# 46 LUNDY'S :  0
# 577 ALVARADO :  0
# 799 MARKET :  74
# 860 FELL :  6
# 3516 SACRAMENTO :  9
# 3518 SACRAMENTO :  0
# 110 SUTTER :  19
# 2 EMBARCADERO CENTER :  0
# 901 MARKET :  50
# 1522 09TH :  0
# 875 37TH :  1
# 474 LOS PALMOS :  0
# 115 TOPAZ :  0
# 117 TOPAZ :  0
# 2106 JACKSON :  12
# 4612 19TH :  0
# 2349 09TH :  0
# 848 26TH :  0
# 980 BAKER :  1
# 2035 LAGUNA :  0
# 1 CALIFORNIA :  809
# 1692 HAIGHT :  0
# 201 CALIFORNIA :  95
# 5431 CALIFORNIA :  3
# 333 BUSH :  130
# 601 CALIFORNIA :  37
# 123 MISSION :  55
# 2288 BROADWAY :  28
# 1330 HAMPSHIRE :  0
# 1309 HOWARD :  0
# 555 MARKET :  94
# 115 ULLOA :  3
# 47 PROSPECT :  1
# 1859 FILBERT :  1
# 250 SUMMIT :  0
# 50 LAGUNA :  75
# 1520 GOUGH :  22
# 420 MONTGOMERY :  56
# 180 MONTGOMERY :  27
# 2841 VALLEJO :  3
# 1017 PORTOLA :  0
# 1 MONTGOMERY :  442
# 120 KEARNY :  162
# 1569 PAGE :  0
# 100 DIAMOND :  7
# 1234 34TH :  2
# 1236 34TH :  0
# 47 LINDA :  0

# %%
# Out:
# 57067

# %%
predictor
# Out:
#                   file_date  estimated cost          proposed use  \
# 0       2013-12-23 00:00:00      55000000.0            APARTMENTS
# 1       2014-03-07 00:00:00        285000.0     1 FAMILY DWELLING
# 2       2014-04-04 00:00:00             1.0                   NaN
# 3       2014-04-04 00:00:00             1.0                   NaN
# 4       2014-04-04 00:00:00             1.0                   NaN
# 5       2014-04-04 00:00:00             1.0                   NaN
# 6       2014-04-04 00:00:00             1.0                   NaN
# 7       2014-04-04 00:00:00             1.0                   NaN
# 8       2014-04-29 00:00:00          6000.0     1 FAMILY DWELLING
# 9       2014-05-22 00:00:00         20000.0               ANTENNA
# 10      2014-06-11 00:00:00         20000.0                OFFICE
# 11      2014-06-11 00:00:00         20000.0                OFFICE
# 12      2014-07-10 00:00:00        130000.0     1 FAMILY DWELLING
# 13      2014-07-24 00:00:00       3000000.0          RETAIL SALES
# 14      2014-07-30 00:00:00          8000.0     2 FAMILY DWELLING
# 15      2014-09-26 00:00:00         20000.0   PRKNG GARAGE/PUBLIC
# 16      2014-10-01 00:00:00          2250.0                   NaN
# 17      2014-11-04 00:00:00          1000.0            APARTMENTS
# 18      2014-12-04 00:00:00          1000.0                OFFICE
# 19      2014-12-16 00:00:00        334022.0   TOURIST HOTEL/MOTEL
# 20      2014-12-17 00:00:00          5000.0                   NaN
# 21      2014-12-18 00:00:00        495000.0            APARTMENTS
# 22      2014-12-18 00:00:00        495000.0            APARTMENTS
# 23      2014-12-29 00:00:00        100000.0  PUBLIC ASSMBLY OTHER
# 24      2015-01-23 00:00:00         40000.0            APARTMENTS
# 25      2015-01-23 00:00:00         40000.0            APARTMENTS
# 26      2015-01-26 00:00:00         45000.0            APARTMENTS
# 27      2015-01-29 00:00:00         44000.0     1 FAMILY DWELLING
# 28      2015-02-19 00:00:00         22000.0                SCHOOL
# 29      2015-02-19 00:00:00         50000.0  FOOD/BEVERAGE HNDLNG
# ...                     ...             ...                   ...
# 519452  2019-01-31 00:00:00          6000.0                OFFICE
# 519453  2019-01-31 00:00:00          6000.0                OFFICE
# 519454  2019-01-31 00:00:00        100000.0            APARTMENTS
# 519455  2019-01-31 00:00:00         19650.0            APARTMENTS
# 519456  2019-01-31 00:00:00         19650.0            APARTMENTS
# 519457  2019-01-31 00:00:00         25000.0     2 FAMILY DWELLING
# 519458  2019-01-31 00:00:00         25000.0     2 FAMILY DWELLING
# 519459  2019-01-31 00:00:00         30000.0            APARTMENTS
# 519460  2019-01-31 00:00:00         30000.0            APARTMENTS
# 519461  2019-01-31 00:00:00         50000.0     2 FAMILY DWELLING
# 519462  2019-01-31 00:00:00         20000.0          RETAIL SALES
# 519463  2019-01-31 00:00:00         20000.0            APARTMENTS
# 519464  2019-01-31 00:00:00         45000.0     1 FAMILY DWELLING
# 519465  2019-01-31 00:00:00         20000.0     2 FAMILY DWELLING
# 519466  2019-01-31 00:00:00         20000.0     2 FAMILY DWELLING
# 519467  2019-01-31 00:00:00             1.0     1 FAMILY DWELLING
# 519468  2019-01-31 00:00:00             1.0     1 FAMILY DWELLING
# 519469  2019-01-31 00:00:00          6000.0     1 FAMILY DWELLING
# 519470  2019-01-31 00:00:00         11800.0     1 FAMILY DWELLING
# 519471  2019-01-31 00:00:00         11800.0     1 FAMILY DWELLING
# 519472  2019-01-31 00:00:00         10000.0     1 FAMILY DWELLING
# 519473  2019-01-31 00:00:00             1.0         MANUFACTURING
# 519474  2019-01-31 00:00:00          1000.0                OFFICE
# 519475  2019-01-31 00:00:00             1.0     1 FAMILY DWELLING
# 519476  2019-01-31 00:00:00             1.0     2 FAMILY DWELLING
# 519477  2019-01-31 00:00:00             1.0     2 FAMILY DWELLING
# 519478  2019-01-31 00:00:00             1.0     2 FAMILY DWELLING
# 519479  2019-01-31 00:00:00             1.0     2 FAMILY DWELLING
# 519480  2019-01-31 00:00:00          3500.0     1 FAMILY DWELLING
# 519481  2019-01-31 00:00:00          3500.0     1 FAMILY DWELLING
#
#         proposed units  proposed stories             address  \
# 0                259.0               6.0   1201 TENNESSEE ST
# 1                  1.0               3.0         435 10TH AV
# 2                  NaN               NaN      1127 MARKET ST
# 3                  NaN               NaN      1127 MARKET ST
# 4                  NaN               NaN      1127 MARKET ST
# 5                  NaN               NaN      1127 MARKET ST
# 6                  NaN               NaN      1127 MARKET ST
# 7                  NaN               NaN      1127 MARKET ST
# 8                  1.0               3.0  3935 WASHINGTON ST
# 9                  0.0               2.0        455 IRWIN ST
# 10                 0.0              12.0         201 POST ST
# 11                 0.0              12.0         209 POST ST
# 12                 1.0               2.0        2371 17TH AV
# 13                 0.0              23.0      1455 MARKET ST
# 14                 2.0               2.0    322 LEXINGTON ST
# 15                 NaN               7.0    2130 OFARRELL ST
# 16                 NaN               NaN       1 HALLIDIE PZ
# 17                26.0               8.0        1299 BUSH ST
# 18                 NaN              26.0         222 02ND ST
# 19                 NaN               6.0  28 CYRIL MAGNIN ST
# 20                 NaN               NaN       2675 GEARY BL
# 21                 3.0               3.0        3507 23RD ST
# 22                 3.0               3.0        3509 23RD ST
# 23                 0.0               1.0         333 POST ST
# 24                 5.0               3.0        1417 05TH AV
# 25                 5.0               3.0        1419 05TH AV
# 26                12.0               3.0      40 BUCHANAN ST
# 27                 1.0               2.0      1627 RIVERA ST
# 28                 0.0               2.0        1111 08TH ST
# 29                 0.0               2.0       744 IRVING ST
# ...                ...               ...                 ...
# 519452             NaN              11.0       500 HOWARD ST
# 519453             NaN              11.0       500 HOWARD ST
# 519454             3.0               3.0    2834 SAN JOSE AV
# 519455             3.0               4.0  4440 CALIFORNIA ST
# 519456             3.0               4.0  4440 CALIFORNIA ST
# 519457             2.0               3.0        4470 24TH ST
# 519458             2.0               3.0        4472 24TH ST
# 519459           449.0              13.0     601 VAN NESS AV
# 519460           449.0              13.0     601 VAN NESS AV
# 519461             2.0               4.0       7039 GEARY BL
# 519462            10.0               3.0      1795 HAIGHT ST
# 519463             5.0               3.0      785 CORBETT AV
# 519464             1.0               3.0  839 NORTH POINT ST
# 519465             2.0               3.0       3440 SCOTT ST
# 519466             2.0               3.0       3442 SCOTT ST
# 519467             1.0               3.0         513 08TH AV
# 519468             1.0               3.0         513 08TH AV
# 519469             1.0               2.0       766 VIENNA ST
# 519470             1.0               2.0       679 VIENNA ST
# 519471             1.0               2.0       679 VIENNA ST
# 519472             1.0               2.0       766 VIENNA ST
# 519473             NaN               3.0      1155 BRYANT ST
# 519474             NaN               2.0       432 BRYANT ST
# 519475             1.0               2.0         647 28TH AV
# 519476             2.0               3.0        2908 BUSH ST
# 519477             2.0               3.0        2910 BUSH ST
# 519478             2.0               3.0        2908 BUSH ST
# 519479             2.0               3.0        2910 BUSH ST
# 519480             1.0               2.0       274 TOPEKA AV
# 519481             1.0               2.0       274 TOPEKA AV
#
#                            list street name            addr2
# 0         [1201, TENNESSEE, ST]   TENNESSEE   1201 TENNESSEE
# 1               [435, 10TH, AV]        10TH         435 10TH
# 2            [1127, MARKET, ST]      MARKET      1127 MARKET
# 3            [1127, MARKET, ST]      MARKET      1127 MARKET
# 4            [1127, MARKET, ST]      MARKET      1127 MARKET
# 5            [1127, MARKET, ST]      MARKET      1127 MARKET
# 6            [1127, MARKET, ST]      MARKET      1127 MARKET
# 7            [1127, MARKET, ST]      MARKET      1127 MARKET
# 8        [3935, WASHINGTON, ST]  WASHINGTON  3935 WASHINGTON
# 9              [455, IRWIN, ST]       IRWIN        455 IRWIN
# 10              [201, POST, ST]        POST         201 POST
# 11              [209, POST, ST]        POST         209 POST
# 12             [2371, 17TH, AV]        17TH        2371 17TH
# 13           [1455, MARKET, ST]      MARKET      1455 MARKET
# 14         [322, LEXINGTON, ST]   LEXINGTON    322 LEXINGTON
# 15         [2130, OFARRELL, ST]    OFARRELL    2130 OFARRELL
# 16            [1, HALLIDIE, PZ]    HALLIDIE       1 HALLIDIE
# 17             [1299, BUSH, ST]        BUSH        1299 BUSH
# 18              [222, 02ND, ST]        02ND         222 02ND
# 19      [28, CYRIL, MAGNIN, ST]       CYRIL  28 CYRIL MAGNIN
# 20            [2675, GEARY, BL]       GEARY       2675 GEARY
# 21             [3507, 23RD, ST]        23RD        3507 23RD
# 22             [3509, 23RD, ST]        23RD        3509 23RD
# 23              [333, POST, ST]        POST         333 POST
# 24             [1417, 05TH, AV]        05TH        1417 05TH
# 25             [1419, 05TH, AV]        05TH        1419 05TH
# 26           [40, BUCHANAN, ST]    BUCHANAN      40 BUCHANAN
# 27           [1627, RIVERA, ST]      RIVERA      1627 RIVERA
# 28             [1111, 08TH, ST]        08TH        1111 08TH
# 29            [744, IRVING, ST]      IRVING       744 IRVING
# ...                         ...         ...              ...
# 519452        [500, HOWARD, ST]      HOWARD       500 HOWARD
# 519453        [500, HOWARD, ST]      HOWARD       500 HOWARD
# 519454    [2834, SAN, JOSE, AV]         SAN    2834 SAN JOSE
# 519455   [4440, CALIFORNIA, ST]  CALIFORNIA  4440 CALIFORNIA
# 519456   [4440, CALIFORNIA, ST]  CALIFORNIA  4440 CALIFORNIA
# 519457         [4470, 24TH, ST]        24TH        4470 24TH
# 519458         [4472, 24TH, ST]        24TH        4472 24TH
# 519459     [601, VAN, NESS, AV]         VAN     601 VAN NESS
# 519460     [601, VAN, NESS, AV]         VAN     601 VAN NESS
# 519461        [7039, GEARY, BL]       GEARY       7039 GEARY
# 519462       [1795, HAIGHT, ST]      HAIGHT      1795 HAIGHT
# 519463       [785, CORBETT, AV]     CORBETT      785 CORBETT
# 519464  [839, NORTH, POINT, ST]       NORTH  839 NORTH POINT
# 519465        [3440, SCOTT, ST]       SCOTT       3440 SCOTT
# 519466        [3442, SCOTT, ST]       SCOTT       3442 SCOTT
# 519467          [513, 08TH, AV]        08TH         513 08TH
# 519468          [513, 08TH, AV]        08TH         513 08TH
# 519469        [766, VIENNA, ST]      VIENNA       766 VIENNA
# 519470        [679, VIENNA, ST]      VIENNA       679 VIENNA
# 519471        [679, VIENNA, ST]      VIENNA       679 VIENNA
# 519472        [766, VIENNA, ST]      VIENNA       766 VIENNA
# 519473       [1155, BRYANT, ST]      BRYANT      1155 BRYANT
# 519474        [432, BRYANT, ST]      BRYANT       432 BRYANT
# 519475          [647, 28TH, AV]        28TH         647 28TH
# 519476         [2908, BUSH, ST]        BUSH        2908 BUSH
# 519477         [2910, BUSH, ST]        BUSH        2910 BUSH
# 519478         [2908, BUSH, ST]        BUSH        2908 BUSH
# 519479         [2910, BUSH, ST]        BUSH        2910 BUSH
# 519480        [274, TOPEKA, AV]      TOPEKA       274 TOPEKA
# 519481        [274, TOPEKA, AV]      TOPEKA       274 TOPEKA
#
# [519482 rows x 9 columns]
